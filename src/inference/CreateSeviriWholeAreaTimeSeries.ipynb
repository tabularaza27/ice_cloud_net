# %% [markdown]
# ## Create Seviri time series - full image
#
# Step by step full image prediction:
# * get matching seviri files in time range
# * read and concat seviri files

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import json
import sys
import os
from datetime import datetime, date, timedelta
import xarray as xr
import pandas as pd
import numpy as np
from pyproj import CRS, Transformer
from satpy import find_files_and_readers

# %%
import socket
import sys

# get host name to check if we are on euler/daint/iac
hostname = socket.gethostname()
print(hostname)
if hostname.startswith("eu"):
    host = "euler"
else:
    host = "iac"

if host == "euler":
    sys.path.append("/cluster/home/kjeggle/sat-cirrus")
    sys.path.append("/cluster/home/kjeggle/sat-cirrus/data")
else:
    sys.path.append("/home/kjeggle/sat-cirrus")
    sys.path.append("/home/kjeggle/sat-cirrus/data")
# Out:
# iacdipl-7

# %%
# todo - these functions are copied from code of the paper amell et al. 2021
from data.data_module import read_seviri_native_file, _resolve_serialisation

# %%
def read_and_crop_seviri_data(filepath, crop=None) -> xr.Dataset:
    """reads and crops spatial extent
    
    args:
        filepath (str):
        crop (tuple): (min, max)
    """
    ds = read_seviri_native_file(filepath)
    ds = _resolve_serialisation(ds)
    ds = add_lonlat(ds)
    if crop:
        lonmin,lonmax,latmin,latmax=crop
        ds = ds.sel(x=slice(lonmax,lonmin),y=slice(latmin,latmax))
        
    return ds

# %%
def add_lonlat(patch: xr.Dataset,
               hor_res: float = 0.01,
               transformer = None):
    """adds lon / lat to patch"""
    if transformer is None:
        # transform lon/lat to cartesian coordinates [m]
        transformer = Transformer.from_crs(seviri_proj, era5_proj, always_xy=True)
        
    patch_lons, patch_lats = transformer.transform(patch.x.values, patch.y.values)
    
    patch = patch.assign(lon=xr.DataArray(patch_lons, dims="x", coords={'x': patch.x.values}),
                         lat=xr.DataArray(patch_lats, dims="y", coords={'y': patch.y.values}))

    patch = patch.assign(latr=lambda x: np.round((np.round(x.lat * (1 / hor_res)) * hor_res).astype('float64'), 4))
    patch = patch.assign(lonr=lambda x: np.round((np.round(x.lon * (1 / hor_res)) * hor_res).astype('float64'), 4))
    
    return patch

# %%
def create_seviri_timeseries(start_time, 
                             end_time, 
                             domain=(-2.732e+06,2.732e+06,-2.996e+06,2.996e+06),
                             seviri_source_dir="/net/n2o/wolke_scratch2/kjeggle/SEVIRI"):
    """
    Args:
        start_time (datetime)
        end_time (datetime)
        domain (tuple): (lonmin,lonmax,latmin,latmax)
        seviri_source_dir (str)
    
    
    """   
    # get available seviri files
    my_files = find_files_and_readers(base_dir=seviri_source_dir,
                                      reader='seviri_l1b_native',
                                      start_time=start_time,
                                      end_time=end_time)["seviri_l1b_native"]
    my_files = np.sort(my_files)
    print(f"{len(my_files)} SEVIRI files found")
    
    # read seviri files and concat along sensing stop dimension
    ds_list = [read_and_crop_seviri_data(fpath, crop=domain) for fpath in my_files]
    print("read all seviri files")
    
    # concat files
    ds = xr.concat(ds_list,dim="sensing_stop")
    print("concatenated all files along time dim")
    
    # remove some parameters -> necessary to be able to save as .nc file
    for i in range(1,12):
        try:
            del ds[f"ch{i}"].attrs['orbital_parameters']
        except KeyError:
            pass
        try:
            del ds[f"ch{i}"].attrs['time_parameters']
            #print(f"deleted time_parameters attribute from ch{i}") 
        except KeyError:
            pass
    
    return ds

# %%
def create_and_save_seviri_timeseries(date_obj,
                                      domain=(-2.732e+06,2.732e+06,-2.996e+06,2.996e+06),
                                      seviri_source_dir="/net/n2o/wolke_scratch2/kjeggle/SEVIRI",
                                      target_dir="/net/n2o/wolke_scratch2/kjeggle/VerticalCloud/DataSmallDomain/SeviriWholeAreaInput/"):
    print("create seviri timeseries for", date_obj)
    
    start_time = datetime.combine(date_obj, datetime.min.time())
    end_time = start_time + timedelta(hours=23,minutes=59)
    
    ds = create_seviri_timeseries(start_time, end_time, domain, seviri_source_dir)
    
    date_str = datetime.strftime(start_time.date(),"%Y%m%d")
    fname = f"seviri_timeseries_{date_str}.nc"
    print(f"save seviri timeseries ({start_time} - {end_time}) to {fname}")
    ds.to_netcdf(os.path.join(target_dir,fname))
    print("\n")
    print("#############")
    print("\n")

# %%
era5_proj = CRS.from_string('EPSG:4326') # latlon
SEVIRI_PROJECTION_SOURCE = "./data/seviri_proj.json"

with open(SEVIRI_PROJECTION_SOURCE, "r") as json_file:
    data = json.load(json_file)
seviri_proj = CRS.from_json_dict(data)

# %%
# create and save dataset for range of dates
start_date = date(2010,6,1)
end_date = date(2010,12,31)
date_list = [start_date + timedelta(days=x) for x in range((end_date-start_date).days+1)]

for d in date_list:
    create_and_save_seviri_timeseries(d)
# Out:
# create seviri timeseries for 2010-06-01
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-06-01 00:00:00 - 2010-06-01 23:59:00) to seviri_timeseries_20100601.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-06-02
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-06-02 00:00:00 - 2010-06-02 23:59:00) to seviri_timeseries_20100602.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-06-03
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-06-03 00:00:00 - 2010-06-03 23:59:00) to seviri_timeseries_20100603.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-06-04
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-06-04 00:00:00 - 2010-06-04 23:59:00) to seviri_timeseries_20100604.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-06-05
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-06-05 00:00:00 - 2010-06-05 23:59:00) to seviri_timeseries_20100605.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-06-06
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-06-06 00:00:00 - 2010-06-06 23:59:00) to seviri_timeseries_20100606.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-06-07
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-06-07 00:00:00 - 2010-06-07 23:59:00) to seviri_timeseries_20100607.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-06-08
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-06-08 00:00:00 - 2010-06-08 23:59:00) to seviri_timeseries_20100608.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-06-09
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-06-09 00:00:00 - 2010-06-09 23:59:00) to seviri_timeseries_20100609.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-06-10
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-06-10 00:00:00 - 2010-06-10 23:59:00) to seviri_timeseries_20100610.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-06-11
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-06-11 00:00:00 - 2010-06-11 23:59:00) to seviri_timeseries_20100611.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-06-12
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-06-12 00:00:00 - 2010-06-12 23:59:00) to seviri_timeseries_20100612.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-06-13
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-06-13 00:00:00 - 2010-06-13 23:59:00) to seviri_timeseries_20100613.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-06-14
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-06-14 00:00:00 - 2010-06-14 23:59:00) to seviri_timeseries_20100614.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-06-15
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-06-15 00:00:00 - 2010-06-15 23:59:00) to seviri_timeseries_20100615.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-06-16
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-06-16 00:00:00 - 2010-06-16 23:59:00) to seviri_timeseries_20100616.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-06-17
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-06
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-11-02 00:00:00 - 2010-11-02 23:59:00) to seviri_timeseries_20101102.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-11-03
# 94 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-11-03 00:00:00 - 2010-11-03 23:59:00) to seviri_timeseries_20101103.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-11-04
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-11-04 00:00:00 - 2010-11-04 23:59:00) to seviri_timeseries_20101104.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-11-05
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-11-05 00:00:00 - 2010-11-05 23:59:00) to seviri_timeseries_20101105.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-11-06
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-11-06 00:00:00 - 2010-11-06 23:59:00) to seviri_timeseries_20101106.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-11-07
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-11-07 00:00:00 - 2010-11-07 23:59:00) to seviri_timeseries_20101107.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-11-08
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-11-08 00:00:00 - 2010-11-08 23:59:00) to seviri_timeseries_20101108.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-11-09
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-11-09 00:00:00 - 2010-11-09 23:59:00) to seviri_timeseries_20101109.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-11-10
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-11-10 00:00:00 - 2010-11-10 23:59:00) to seviri_timeseries_20101110.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-11-11
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-11-11 00:00:00 - 2010-11-11 23:59:00) to seviri_timeseries_20101111.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-11-12
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-11-12 00:00:00 - 2010-11-12 23:59:00) to seviri_timeseries_20101112.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-11-13
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-11-13 00:00:00 - 2010-11-13 23:59:00) to seviri_timeseries_20101113.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-11-14
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-11-14 00:00:00 - 2010-11-14 23:59:00) to seviri_timeseries_20101114.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-11-15
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-11-15 00:00:00 - 2010-11-15 23:59:00) to seviri_timeseries_20101115.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-11-16
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-11-16 00:00:00 - 2010-11-16 23:59:00) to seviri_timeseries_20101116.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-11-17
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-11-17 00:00:00 - 2010-11-17 23:59:00) to seviri_timeseries_20101117.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-11-18
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-11-18 00:00:00 - 2010-11-18 23:59:00) to seviri_timeseries_20101118.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-11-19
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-11-19 00:00:00 - 2010-11-19 23:59:00) to seviri_timeseries_20101119.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-11-20
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-11-20 00:00:00 - 2010-11-20 23:59:00) to seviri_timeseries_20101120.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-11-21
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-11-21 00:00:00 - 2010-11-21 23:59:00) to seviri_timeseries_20101121.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-11-22
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-11-22 00:00:00 - 2010-11-22 23:59:00) to seviri_timeseries_20101122.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-11-23
# 96 SEVIRI files found
# read all seviri files
# concatenated all files along time dim
# save seviri timeseries (2010-11-23 00:00:00 - 2010-11-23 23:59:00) to seviri_timeseries_20101123.nc
#
#
# #############
#
#
# create seviri timeseries for 2010-11-24
# 96 SEVIRI files found
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[20], line 7
#       4 date_list = [start_date + timedelta(days=x) for x in range((end_date-start_date).days+1)]
#       6 for d in date_list:
# ----> 7     create_and_save_seviri_timeseries(d)
#
# Cell In[18], line 10, in create_and_save_seviri_timeseries(date_obj, domain, seviri_source_dir, target_dir)
#       7 start_time = datetime.combine(date_obj, datetime.min.time())
#       8 end_time = start_time + timedelta(hours=23,minutes=59)
# ---> 10 ds = create_seviri_timeseries(start_time, end_time, domain, seviri_source_dir)
#      12 date_str = datetime.strftime(start_time.date(),"%Y%m%d")
#      13 fname = f"seviri_timeseries_{date_str}.nc"
#
# Cell In[17], line 23, in create_seviri_timeseries(start_time, end_time, domain, seviri_source_dir)
#      20 print(f"{len(my_files)} SEVIRI files found")
#      22 # read seviri files and concat along sensing stop dimension
# ---> 23 ds_list = [read_and_crop_seviri_data(fpath, crop=domain) for fpath in my_files]
#      24 print("read all seviri files")
#      26 # concat files
#
# Cell In[17], line 23, in <listcomp>(.0)
#      20 print(f"{len(my_files)} SEVIRI files found")
#      22 # read seviri files and concat along sensing stop dimension
# ---> 23 ds_list = [read_and_crop_seviri_data(fpath, crop=domain) for fpath in my_files]
#      24 print("read all seviri files")
#      26 # concat files
#
# Cell In[15], line 8, in read_and_crop_seviri_data(filepath, crop)
#       1 def read_and_crop_seviri_data(filepath, crop=None) -> xr.Dataset:
#       2     """reads and crops spatial extent
#       3
#       4     args:
#       5         filepath (str):
#       6         crop (tuple): (min, max)
#       7     """
# ----> 8     ds = read_seviri_native_file(filepath)
#       9     ds = _resolve_serialisation(ds)
#      10     ds = add_lonlat(ds)
#
# File ~/sat-cirrus/data/amell_et_al_data.py:1538, in read_seviri_native_file(filepath)
#    1530 def read_seviri_native_file(filepath: str) -> xr.Dataset:
#    1531     """Reads a SEVIRI MSG Level 1.5 file in native format and returns it with
#    1532     all channels except the HRV channel loaded as an xarray Dataset
#    1533
#    (...)
#    1536
#    1537     Returns the described xarray Dataset."""
# -> 1538     scn = satpy.Scene(filenames=[filepath], reader='seviri_l1b_native')
#    1540     # Load all channels except HRV
#    1541     with warnings.catch_warnings():
#    1542         # Ignore warning messages that come from satpy
#
# File ~/miniconda3/envs/satpy/lib/python3.11/site-packages/satpy/scene.py:133, in Scene.__init__(self, filenames, reader, filter_parameters, reader_kwargs)
#     130 if filenames:
#     131     filenames = convert_remote_files_to_fsspec(filenames, storage_options)
# --> 133 self._readers = self._create_reader_instances(filenames=filenames,
#     134                                               reader=reader,
#     135                                               reader_kwargs=cleaned_reader_kwargs)
#     136 self._datasets = DatasetDict()
#     137 self._wishlist = set()
#
# File ~/miniconda3/envs/satpy/lib/python3.11/site-packages/satpy/scene.py:154, in Scene._create_reader_instances(self, filenames, reader, reader_kwargs)
#     149 def _create_reader_instances(self,
#     150                              filenames=None,
#     151                              reader=None,
#     152                              reader_kwargs=None):
#     153     """Find readers and return their instances."""
# --> 154     return load_readers(filenames=filenames,
#     155                         reader=reader,
#     156                         reader_kwargs=reader_kwargs)
#
# File ~/miniconda3/envs/satpy/lib/python3.11/site-packages/satpy/readers/__init__.py:575, in load_readers(filenames, reader, reader_kwargs)
#     573 loadables = reader_instance.select_files_from_pathnames(readers_files)
#     574 if loadables:
# --> 575     reader_instance.create_filehandlers(
#     576             loadables,
#     577             fh_kwargs=reader_kwargs_without_filter[None if reader is None else reader[idx]])
#     578     reader_instances[reader_instance.name] = reader_instance
#     579     remaining_filenames -= set(loadables)
#
# File ~/miniconda3/envs/satpy/lib/python3.11/site-packages/satpy/readers/yaml_reader.py:616, in FileYAMLReader.create_filehandlers(self, filenames, fh_kwargs)
#     614 # load files that we know about by creating the file handlers
#     615 for filetype, filetype_info in self.sorted_filetype_items():
# --> 616     filehandlers = self._new_filehandlers_for_filetype(filetype_info,
#     617                                                        filename_set,
#     618                                                        fh_kwargs=fh_kwargs)
#     620     if filehandlers:
#     621         created_fhs[filetype] = filehandlers
#
# File ~/miniconda3/envs/satpy/lib/python3.11/site-packages/satpy/readers/yaml_reader.py:604, in FileYAMLReader._new_filehandlers_for_filetype(self, filetype_info, filenames, fh_kwargs)
#     600 filehandler_iter = self._new_filehandler_instances(filetype_info,
#     601                                                    filename_iter,
#     602                                                    fh_kwargs=fh_kwargs)
#     603 filtered_iter = self.filter_fh_by_metadata(filehandler_iter)
# --> 604 return list(filtered_iter)
#
# File ~/miniconda3/envs/satpy/lib/python3.11/site-packages/satpy/readers/yaml_reader.py:572, in FileYAMLReader.filter_fh_by_metadata(self, filehandlers)
#     570 def filter_fh_by_metadata(self, filehandlers):
#     571     """Filter out filehandlers using provide filter parameters."""
# --> 572     for filehandler in filehandlers:
#     573         filehandler.metadata['start_time'] = filehandler.start_time
#     574         filehandler.metadata['end_time'] = filehandler.end_time
#
# File ~/miniconda3/envs/satpy/lib/python3.11/site-packages/satpy/readers/yaml_reader.py:513, in FileYAMLReader._new_filehandler_instances(self, filetype_info, filename_items, fh_kwargs)
#     510     warnings.warn(str(err) + ' for {}'.format(filename), stacklevel=4)
#     511     continue
# --> 513 yield filetype_cls(filename, filename_info, filetype_info, *req_fh, **fh_kwargs)
#
# File ~/miniconda3/envs/satpy/lib/python3.11/site-packages/satpy/readers/seviri_l1b_native.py:118, in NativeMSGFileHandler.__init__(self, filename, filename_info, filetype_info, calib_mode, fill_disk, ext_calib_coefs, include_raw_metadata, mda_max_array_size)
#     114 self.trailer = {}
#     116 # Read header, prepare dask-array, read trailer and initialize image boundaries
#     117 # Available channels are known only after the header has been read
# --> 118 self.header_type = get_native_header(self._has_archive_header())
#     119 self._read_header()
#     120 self.dask_array = da.from_array(self._get_memmap(), chunks=(CHUNK_SIZE,))
#
# File ~/miniconda3/envs/satpy/lib/python3.11/site-packages/satpy/readers/seviri_l1b_native.py:127, in NativeMSGFileHandler._has_archive_header(self)
#     125 """Check whether the file includes an ASCII archive header."""
#     126 ascii_startswith = b'FormatName                  : NATIVE'
# --> 127 with open(self.filename, mode='rb') as istream:
#     128     return istream.read(36) == ascii_startswith
#
# OSError: [Errno 512] Unknown error 512: '/net/n2o/wolke_scratch2/kjeggle/SEVIRI/MSG2-SEVI-MSG15-0100-NA-20101124004242.462000000Z-NA.nat'

# %% [markdown]
# ### prep seviri aux file for meta data retrieval

# %%
sev_aux = xr.open_dataset("/net/n2o/wolke_scratch2/kjeggle/VerticalCloud/DataSmallDomain/seviri_aux.nc",decode_times=False)

# %%
sev_aux = add_lonlat(sev_aux)

lonmin = -2.732e+06
lonmax = 2.732e+06
latmin = -2.996e+06
latmax = 2.996e+06

sev_aux = sev_aux.sel(x=slice(lonmax,lonmin),y=slice(latmin,latmax))

# %%
sev_aux.to_netcdf("/net/n2o/wolke_scratch2/kjeggle/VerticalCloud/DataSmallDomain/seviri_aux_latlon.nc")

# %% [markdown]
# ### manual execution of seviri time series creation

# %%
seviri_source_dir = "/net/n2o/wolke_scratch2/kjeggle/SEVIRI"

# %%
# Niamey casestudy
#datetime(2006, 8, 22, 0, 0, 0)-datetime(2006, 8, 22, 23, 59, 0))["

# %%
my_files = find_files_and_readers(base_dir=seviri_source_dir,
                                  reader='seviri_l1b_native',
                                  start_time=datetime(2012, 12, 22, 0, 0, 0),
                                  end_time=datetime(2012, 12, 22, 23, 59, 0))["seviri_l1b_native"]

# %%
my_files
# Out:
# ['/net/n2o/wolke_scratch2/kjeggle/SEVIRI/MSG3-SEVI-MSG15-0100-NA-20121222172743.073000000Z-NA.nat',
#  '/net/n2o/wolke_scratch2/kjeggle/SEVIRI/MSG3-SEVI-MSG15-0100-NA-20121222012742.803000000Z-NA.nat',
#  '/net/n2o/wolke_scratch2/kjeggle/SEVIRI/MSG3-SEVI-MSG15-0100-NA-20121222035742.811000000Z-NA.nat',
#  '/net/n2o/wolke_scratch2/kjeggle/SEVIRI/MSG2-SEVI-MSG15-0100-NA-20121222204241.923000000Z-NA.nat',
#  '/net/n2o/wolke_scratch2/kjeggle/SEVIRI/MSG3-SEVI-MSG15-0100-NA-20121222141242.613000000Z-NA.nat',
#  '/net/n2o/wolke_scratch2/kjeggle/SEVIRI/MSG3-SEVI-MSG15-0100-NA-20121222201243.407000000Z-NA.nat',
#  '/net/n2o/wolke_scratch2/kjeggle/SEVIRI/MSG2-SEVI-MSG15-0100-NA-20121222224241.204000000Z-NA.nat',
#  '/net/n2o/wolke_scratch2/kjeggle/SEVIRI/MSG3-SEVI-MSG15-0100-NA-20121222071243.316000000Z-NA.nat',
#  '/net/n2o/wolke_scratch2/kjeggle/SEVIRI/MSG2-SEVI-MSG15-0100-NA-20121222115742.501000000Z-NA.nat',
#  '/net/n2o/wolke_scratch2/kjeggle/SEVIRI/MSG3-SEVI-MSG15-0100-NA-20121222232742.655000000Z-NA.nat',
#  '/net/n2o/wolke_scratch2/kjeggle/SEVIRI/MSG2-SEVI-MSG15-0100-NA-20121222134241.678000000Z-NA.nat',
#  '/net/n2o/wolke_scratch2/kjeggle/SEVIRI/MSG3-SEVI-MSG15-0100-NA-20121
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/satpy/readers/seviri_l1b_native.py:119: UserWarning: The quality flag for this file indicates not OK. Use this data with caution!
#   self._read_header()
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/satpy/readers/seviri_l1b_native.py:119: UserWarning: The quality flag for this file indicates not OK. Use this data with caution!
#   self._read_header()
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/satpy/readers/seviri_l1b_native.py:119: UserWarning: The quality flag for this file indicates not OK. Use this data with caution!
#   self._read_header()
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/satpy/readers/seviri_l1b_native.py:119: UserWarning: The quality flag for this file indicates not OK. Use this data with caution!
#   self._read_header()
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/satpy/readers/seviri_l1b_native.py:119: UserWarning: The quality flag for this file indicates not OK. Use this data with caution!
#   self._read_header()
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/satpy/readers/seviri_l1b_native.py:119: UserWarning: The quality flag for this file indicates not OK. Use this data with caution!
#   self._read_header()
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/satpy/readers/seviri_l1b_native.py:119: UserWarning: The quality flag for this file indicates not OK. Use this data with caution!
#   self._read_header()
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/satpy/readers/seviri_l1b_native.py:119: UserWarning: The quality flag for this file indicates not OK. Use this data with caution!
#   self._read_header()
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/satpy/readers/seviri_l1b_native.py:119: UserWarning: The quality flag for this file indicates not OK. Use this data with caution!
#   self._read_header()
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/satpy/readers/seviri_l1b_native.py:119: UserWarning: The quality flag for this file indicates not OK. Use this data with caution!
#   self._read_header()
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# /home/kjeggle/miniconda3/envs/satpy/lib/python3.11/site-packages/pyproj/crs/crs.py:1286: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)

# %%
ds = xr.concat(ds_list,dim="sensing_stop")

# %%
ds

# %%
for i in range(1,12):
    try:
        del ds[f"ch{i}"].attrs['orbital_parameters']
    except KeyError:
        pass
    try:
        del ds[f"ch{i}"].attrs['time_parameters']
        #print(f"deleted time_parameters attribute from ch{i}") 
    except KeyError:
        pass

# %%
# %%time
ds.to_netcdf("/net/n2o/wolke_scratch2/kjeggle/VerticalCloud/DataSmallDomain/SeviriWholeAreaInput/seviri_whole_area_sample_full_day_20240116.nc")
# Out:
# CPU times: user 313 ms, sys: 12 s, total: 12.3 s
# Wall time: 28.9 s

# %%
# Niamey station location
niamey_lat= 13.4773
niamey_lon = 2.1758

# niamey_lat_id = 1485

# %%
niamey_x_id = np.argmin(np.abs((ds.isel(sensing_stop=0).lon.values - niamey_lon)))
niamey_y_id = np.argmin(np.abs((ds.isel(sensing_stop=0).lat.values - niamey_lat)))

# %%
print(f"identified lon {ds.isel(sensing_stop=1,x=niamey_x_id).lon.values:.4f} vs actual lon: {niamey_lon} | index in seviri grid: {niamey_x_id}")
print(f"identified lat {ds.isel(sensing_stop=1,y=niamey_y_id).lat.values:.4f} vs actual lat: {niamey_lat} | index in seviri grid: {niamey_y_id}")

# %%
lat_to_km = Transformer.from_crs(era5_proj,seviri_proj, always_xy=True)

# %%
era5_proj

# %%
x,y = lat_to_km.transform(niamey_lon,niamey_lat)

# %%
x

# %%
y

# %%
ds.sel(x=x,y=y,method="nearest")
